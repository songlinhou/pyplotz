# %% [markdown]
# # Pyplotz

# %% [markdown]
# Using matplotlib with Chinese characters can be kindly of tricky. So this light weight library is designed to help you handle that problem. It simply works.

# %% [markdown]
# It has been tested on
#
# * Mac OS
#
# More platforms will be accomendated SOON.

# %% [markdown]
# This is a small demo to show you how to use pyplotz.

# %%
from pyplotz.pyplotz import PyplotZ
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
pltz = PyplotZ() # create an instance

# %%
pltz.set_figure_size(10,5) # 
pltz.enable_chinese() # enable chinese so you can use chinese characters
pltz.plot(np.linspace(-10,10),np.sin(np.linspace(-10,10)),'b', label='sin数据',alpha=0.7)
pltz.plot(np.linspace(-10,10),np.cos(np.linspace(-10,10)),'r', label='cos数据',alpha=0.7)
pltz.title("数据图")
pltz.xlabel("横坐标")
pltz.ylabel("纵坐标")
plt.grid() # you can use matplotlib API and pyplotz interchangeably.
pltz.legend() # use legend function from pltz to show Chinese properly
pltz.automate_font_size(scale=0.8) # always put this statement at last(scale controls the overall font size)
# Out:
# [Errno 2] No such file or directory: 'plot_zh.ttf'
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-e442afecc22d> in <module>()
#       3 pltz.plot(np.linspace(-10,10),np.sin(np.linspace(-10,10)),'b', label='sin数据',alpha=0.7)
#       4 pltz.plot(np.linspace(-10,10),np.cos(np.linspace(-10,10)),'r', label='cos数据',alpha=0.7)
# ----> 5 pltz.title("数据图")
#       6 pltz.xlabel("横坐标")
#       7 pltz.ylabel("纵坐标")
#
# /Users/MacBook/anaconda2/lib/python2.7/site-packages/pyplotz/pyplotz.pyc in title(self, *arg, **kwargs)
#      89                 kwargs['fontproperties'] = self.zh_font
#      90                 arg = [self.__utf8__(a) for a in arg]
# ---> 91         plt.title(*arg,**kwargs)
#      92     def text(self,*arg,**kwargs):
#      93         if hasattr(self,'zh_font'):
#
# /Users/MacBook/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in title(s, *args, **kwargs)
#    1463
#    1464     """
# -> 1465     return gca().set_title(s, *args, **kwargs)
#    1466
#    1467 ## Axis ##
#
# /Users/MacBook/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in set_title(self, label, fontdict, loc, **kwargs)
#     184             'verticalalignment': 'baseline',
#     185             'horizontalalignment': loc.lower()}
# --> 186         title.set_text(label)
#     187         title.update(default)
#     188         if fontdict is not None:
#
# /Users/MacBook/anaconda2/lib/python2.7/site-packages/matplotlib/text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe6 in position 0: ordinal not in range(128)
